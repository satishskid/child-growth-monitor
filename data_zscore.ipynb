# %%
# !pip3 install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd
import json
import requests
FIREBASE_URL = "https://childmonitoring-951c3-default-rtdb.firebaseio.com/Users.json"

# %%
data = {
    'goutham': {
        'age': '78',
        'id':'2',
        'gender':'boy',
        'height': '110',
        'mail': 'goutham@gmail.com',
        'name': 'goutham',
        'password': 'G@210457',
        'weight': '20'
    },
    'john123': {
        'age': '65',
        'id':'3',
        'gender':'boy',
        'height': '130',
        'mail': 'john123@gmail.com',
        'name': 'John',
        'password': 'pass456',
        'weight': '19'
    },
    'bharani': {
        'age': '83',
        'id':'4',
        'gender':'girl',
        'height': '141',
        'mail': 'bharani@gmail.com',
        'name': 'Bharani',
        'password': 'Bha@210457',
        'weight': '28'
    }
}

# Sending the data to Firebase
response = requests.put(FIREBASE_URL, json=data)

if response.status_code == 200:
    print("Data pushed successfully:", response.json())
else:
    print("Error:", response.status_code, response.text)
# Out:
# Data pushed successfully: {'bharani': {'age': '83', 'gender': 'girl', 'height': '141', 'id': '4', 'mail': 'bharani@gmail.com', 'name': 'Bharani', 'password': 'Bha@210457', 'weight': '28'}, 'goutham': {'age': '78', 'gender': 'boy', 'height': '110', 'id': '2', 'mail': 'goutham@gmail.com', 'name': 'goutham', 'password': 'G@210457', 'weight': '20'}, 'john123': {'age': '65', 'gender': 'boy', 'height': '130', 'id': '3', 'mail': 'john123@gmail.com', 'name': 'John', 'password': 'pass456', 'weight': '19'}}

# %%
# Your Firebase Realtime Database URL

response = requests.get(FIREBASE_URL)

if response.status_code == 200:
    data = response.json()
    print("Retrieved data:", data)
else:
    print("Error:", response.status_code, response.text)
# Out:
# Retrieved data: {'bharani': {'age': '83', 'gender': 'girl', 'height': '141', 'id': '4', 'mail': 'bharani@gmail.com', 'name': 'Bharani', 'password': 'Bha@210457', 'weight': '28'}, 'goutham': {'age': '78', 'gender': 'boy', 'height': '110', 'id': '2', 'mail': 'goutham@gmail.com', 'name': 'goutham', 'password': 'G@210457', 'weight': '20'}, 'john123': {'age': '65', 'gender': 'boy', 'height': '130', 'id': '3', 'mail': 'john123@gmail.com', 'name': 'John', 'password': 'pass456', 'weight': '19'}}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#                     bharani            goutham            john123
# age                      83                 78                 65
# gender                 girl                boy                boy
# height                  141                110                130
# id                        4                  2                  3
# mail      bharani@gmail.com  goutham@gmail.com  john123@gmail.com
# name                Bharani            goutham               John
# password         Bha@210457           G@210457            pass456
# weight                   28                 20                 19

# %%
df = df.T
df["age"] = pd.to_numeric(df["age"])
df["height"] = pd.to_numeric(df["height"])
df["weight"] = pd.to_numeric(df["weight"])
df["BMI"] = round((df["weight"]*10000)/(df["height"]**2),2)
print(df)
# Out:
#          age gender  height id               mail     name    password  \
# bharani   83   girl     141  4  bharani@gmail.com  Bharani  Bha@210457
# goutham   78    boy     110  2  goutham@gmail.com  goutham    G@210457
# john123   65    boy     130  3  john123@gmail.com     John     pass456
#
#          weight    BMI
# bharani      28  14.08
# goutham      20  16.53
# john123      19  11.24

# %%
df_boy = df[df['gender'] == 'boy']
df_girl = df[df['gender'] == 'girl']

# %%
print('boy_data')
print(df_boy)
print('girl_data')
print(df_girl)
# Out:
# boy_data
#          age gender  height id               mail     name  password  weight  \
# goutham   78    boy     110  2  goutham@gmail.com  goutham  G@210457      20
# john123   65    boy     130  3  john123@gmail.com     John   pass456      19
#
#            BMI
# goutham  16.53
# john123  11.24
# girl_data
#          age gender  height id               mail     name    password  \
# bharani   83   girl     141  4  bharani@gmail.com  Bharani  Bha@210457
#
#          weight    BMI
# bharani      28  14.08

# %%
bh = pd.read_excel("HFA_Boys.xlsx")
bh['age']= bh['Month']
bh = bh.drop("Month",axis = 1)
print(bh)
# Out:
#      L         M        S   StDev   SD5neg   SD4neg   SD3neg   SD2neg  \
# 0    1  110.2647  0.04164  4.5914   87.308   91.899   96.490  101.082
# 1    1  110.8006  0.04172  4.6226   87.688   92.310   96.933  101.555
# 2    1  111.3338  0.04180  4.6538   88.065   92.719   97.373  102.026
# 3    1  111.8636  0.04187  4.6837   88.445   93.129   97.812  102.496
# 4    1  112.3895  0.04195  4.7147   88.816   93.531   98.245  102.960
# ..  ..       ...      ...     ...      ...      ...      ...      ...
# 163  1  176.4453  0.04168  7.3542  139.674  147.028  154.383  161.737
# 164  1  176.4724  0.04159  7.3395  139.775  147.114  154.454  161.793
# 165  1  176.4976  0.04150  7.3247  139.874  147.199  154.524  161.848
# 166  1  176.5211  0.04142  7.3115  139.964  147.275  154.587  161.898
# 167  1  176.5432  0.04134  7.2983  140.052  147.350  154.648  161.947
#
#       SD1neg      SD0      SD1      SD2      SD3      SD4  age
# 0    105.673  110.265  114.856  119.448  124.039  128.630   61
# 1    106.178  110.801  115.423  120.046  124.668  129.291   62
# 2    106.680  111.334  115.988  120.641  125.295  129.949   63
# 3    107.180  111.864  116.547  121.231  125.915  130.599   64
# 4    107.675  112.390  117.104  121.819  126.534  131.248   65
# ..       ...      ...      ...      ...      ...      ...  ...
# 163  169.091  176.445  183.800  191.154  198.508  205.862  224
# 164  169.133  176.472  183.812  191.151  198.491  205.830  225
# 165  169.173  176.498  183.822  191.147  198.472  205.796  226
# 166  169.210  176.521  183.833  191.144  198.456  205.767  227
# 167  169.245  176.543  183.841  191.140  198.438  205.736  228
#
# [168 rows x 15 columns]

# %%
print(df_boy)
# Out:
#          age gender  height id               mail     name  password  weight  \
# goutham   78    boy     110  2  goutham@gmail.com  goutham  G@210457      20
# john123   65    boy     130  3  john123@gmail.com     John   pass456      19
#
#            BMI
# goutham  16.53
# john123  11.24

# %%
height_df_boy = pd.DataFrame()
height_df_boy['age'] = df_boy['age']
height_df_boy['id'] = df_boy['id']
height_df_boy['height'] = df_boy['height']
merged_bh = pd.merge(height_df_boy, bh, left_on='age', right_on='age', how='left')
merged_bh.set_index(df_boy.index, inplace=True)
# print(merged_bh)
# Calculate L * M * S and create a new column in df_boy
merged_bh['HZ'] = ((merged_bh['height']/merged_bh['M'])**merged_bh['L'] -1)/(merged_bh['L'] * merged_bh['S'])
# print(merged_df_boy)
# print(merged_df_boy['HZ'])
# Now you can use merged_df_boy to see the updated DataFrame
height_df_boy = merged_bh

# Show the updated df_boy with the new column
print(height_df_boy)
# Out:
#          age id  height  L         M        S   StDev  SD5neg  SD4neg  \
# goutham   78  2     110  1  118.8700  0.04295  5.1055  93.343  98.448
# john123   65  3     130  1  112.3895  0.04195  4.7147  88.816  93.531
#
#           SD3neg   SD2neg   SD1neg     SD0      SD1      SD2      SD3  \
# goutham  103.554  108.659  113.765  118.87  123.975  129.081  134.186
# john123   98.245  102.960  107.675  112.39  117.104  121.819  126.534
#
#              SD4        HZ
# goutham  139.292 -1.737353
# john123  131.248  3.735201

# %%
weight_df_boy = pd.DataFrame()
weight_df_boy[['age','id','weight']] = df_boy[['age','id','weight']]
print(weight_df_boy)
# Out:
#          age id  weight
# goutham   78  2      20
# john123   65  3      19

# %%
bw = pd.read_excel("WFA_Boys.xlsx")
bw['age']=bw['Month']
bw = bw.drop('Month',axis=1)
print(bw)
# Out:
#          L        M        S  SD4neg  SD3neg  SD2neg  SD1neg     SD0     SD1  \
# 0  -0.2026  18.5057  0.12988  11.070  12.718  14.367  16.279  18.506  21.109
# 1  -0.2130  18.6802  0.13028  11.171  12.833  14.496  16.428  18.680  21.319
# 2  -0.2234  18.8563  0.13067  11.272  12.950  14.627  16.578  18.856  21.530
# 3  -0.2338  19.0340  0.13105  11.376  13.067  14.759  16.729  19.034  21.744
# 4  -0.2443  19.2132  0.13142  11.480  13.186  14.892  16.882  19.213  21.959
# 5  -0.2548  19.3940  0.13178  11.587  13.307  15.027  17.036  19.394  22.176
# 6  -0.2653  19.5765  0.13213  11.694  13.429  15.164  17.192  19.576  22.395
# 7  -0.2758  19.7607  0.13246  11.804  13.553  15.302  17.350  19.761  22.615
# 8  -0.2864  19.9468  0.13279  11.915  13.679  15.442  17.509  19.947  22.839
# 9  -0.2969  20.1344  0.13311  12.027  13.805  15.583  17.670  20.134  23.063
# 10 -0.3075  20.3235  0.13342  12.141  13.934  15.726  17.832  20.324  23.290
# 11 -0.3180  20.5137  0.13372  12.256  14.063  15.870  17.996  20.514  23.517
# 12 -0.3285  20.7052  0.13402  12.371  14.193  16.015  18.160  20.705  23.747
# 13 -0.3390  20.8979  0.13432  12.488  14.324  16.160  18.326  20.898  23.978
# 14 -0.3494  21.0918  0.13462  12.605  14.456  16.307  18.492  21.092  24.210
# 15 -0.3598  21.2870  0.13493  12.722  14.588  16.454  18.659  21.287  24.445
# 16 -0.3701  21.4833  0.13523  12.841  14.721  16.602  18.828  21.483  24.680
# 17 -0.3804  21.6810  0.13554  12.960  14.855  16.751  18.997  21.681  24.918
# print(merged_bw)
# Calculate L * M * S and create a new column in df_boy
merged_bw['WZ'] = ((merged_bw['weight']/merged_bw['M'])**merged_bw['L'] -1)/(merged_bw['L'] * merged_bw['S'])
# print(merged_df_boy)
# print(merged_df_boy['WZ'])
# Now you can use merged_df_boy to see the updated DataFrame
weight_df_boy = merged_bw

# Show the updated df_boy with the new column
print(weight_df_boy)
# Out:
#          age id  weight       L        M        S  SD4neg  SD3neg  SD2neg  \
# goutham   78  2      20 -0.3804  21.6810  0.13554   12.96  14.855  16.751
# john123   65  3      19 -0.2443  19.2132  0.13142   11.48  13.186  14.892
#
#          SD1neg     SD0     SD1     SD2     SD3     SD4        WZ
# goutham  18.997  21.681  24.918  28.862  33.723  38.583 -0.604660
# john123  16.882  19.213  21.959  25.210  29.083  32.956 -0.085023

# %%
bb = pd.read_excel("BFA_Boys.xlsx")
bb['age']=bb['Month']
bb = bb.drop('Month',axis=1)
print(bb)
# Out:
#           L        M        S  SD4neg  SD3neg  SD2neg  SD1neg     SD0     SD1  \
# 0   -0.7387  15.2641  0.08390  11.204  12.118  13.031  14.071  15.264  16.645
# 1   -0.7621  15.2616  0.08414  11.204  12.115  13.027  14.066  15.262  16.648
# 2   -0.7856  15.2604  0.08439  11.204  12.114  13.024  14.063  15.260  16.653
# 3   -0.8089  15.2605  0.08464  11.205  12.114  13.022  14.061  15.260  16.659
# 4   -0.8322  15.2619  0.08490  11.207  12.114  13.021  14.060  15.262  16.667
# ..      ...      ...      ...     ...     ...     ...     ...     ...     ...
# 163 -0.9048  22.0374  0.12911  14.148  15.811  17.473  19.504  22.037  25.281
# 164 -0.8892  22.0760  0.12920  14.151  15.823  17.495  19.535  22.076  25.324
# 165 -0.8735  22.1140  0.12930  14.153  15.834  17.515  19.564  22.114  25.366
# 166 -0.8578  22.1514  0.12939  14.155  15.845  17.535  19.594  22.151  25.408
# 167 -0.8419  22.1883  0.12948  14.156  15.855  17.554  19.622  22.188  25.449
#
#         SD2     SD3     SD4  age
# 0    18.259  20.166  22.072   61
# 1    18.273  20.200  22.127   62
# 2    18.290  20.238  22.186   63
# 3    18.308  20.277  22.247   64
# 4    18.328  20.320  22.312   65
# ..      ...     ...     ...  ...
# 163  29.572  35.503  41.434  224
# 164  29.609  35.507  41.406  225
# 165  29.646  35.512  41.378  226
# 166  29.681  35.515  41.348  227
# 167  29.716  35.516  41.317  228
#
# [168 rows x 13 columns]

# %%
bmi_df_boy = pd.DataFrame()
bmi_df_boy[['age','id','BMI']] = df_boy[['age','id','BMI']]
print(bmi_df_boy)
# Out:
#          age id    BMI
# goutham   78  2  16.53
# john123   65  3  11.24

# %%
merged_bb = pd.DataFrame()
# print(merged_bb)
merged_bb = pd.merge(bmi_df_boy, bb, left_on='age', right_on='age', how='left')
merged_bb.set_index(df_boy.index, inplace=True)
# print(merged_bb)
# Calculate L * M * S and create a new column in df_boy
merged_bb['BZ'] = ((merged_bb['BMI']/merged_bb['M'])**merged_bb['L'] -1)/(merged_bb['L'] * merged_bb['S'])
# print(merged_bb)
# print(merged_bb['BZ'])
# Now you can use merged_df_boy to see the updated DataFrame
bmi_df_boy = merged_bb

# Show the updated df_boy with the new column
print(bmi_df_boy)
# Out:
#          age id    BMI       L        M        S  SD4neg  SD3neg  SD2neg  \
# goutham   78  2  16.53 -1.1230  15.3825  0.08865  11.292  12.189  13.086
# john123   65  3  11.24 -0.8322  15.2619  0.08490  11.207  12.114  13.021
#
#          SD1neg     SD0     SD1     SD2     SD3     SD4        BZ
# goutham  14.136  15.382  16.888  18.745  21.097  23.449  0.779658
# john123  14.060  15.262  16.667  18.328  20.320  22.312 -4.102910

# %%
## for girls

# %%
gh = pd.read_excel("HFA_girls.xlsx")
gh['age']= gh['Month']
gh = gh.drop("Month",axis = 1)
print(gh)
# Out:
#      L         M        S   StDev   SD5neg   SD4neg   SD3neg   SD2neg  \
# 0    1  109.6016  0.04355  4.7731   85.736   90.509   95.282  100.055
# 1    1  110.1258  0.04364  4.8059   86.096   90.902   95.708  100.514
# 2    1  110.6451  0.04373  4.8385   86.453   91.291   96.130  100.968
# 3    1  111.1596  0.04382  4.8710   86.805   91.676   96.547  101.418
# 4    1  111.6696  0.04390  4.9023   87.158   92.060   96.963  101.865
# ..  ..       ...      ...     ...      ...      ...      ...      ...
# 163  1  163.1418  0.04023  6.5632  130.326  136.889  143.452  150.015
# 164  1  163.1469  0.04019  6.5569  130.363  136.919  143.476  150.033
# 165  1  163.1508  0.04016  6.5521  130.390  136.942  143.494  150.047
# 166  1  163.1534  0.04012  6.5457  130.425  136.971  143.516  150.062
# 167  1  163.1548  0.04009  6.5409  130.450  136.991  143.532  150.073
#
#       SD1neg      SD0      SD1      SD2      SD3      SD4  age
# 0    104.828  109.602  114.375  119.148  123.921  128.694   61
# 1    105.320  110.126  114.932  119.738  124.543  129.349   62
# 2    105.807  110.645  115.484  120.322  125.161  129.999   63
# 3    106.289  111.160  116.031  120.902  125.773  130.644   64
# 4    106.767  111.670  116.572  121.474  126.376  131.279   65
# ..       ...      ...      ...      ...      ...      ...  ...
# 163  156.579  163.142  169.705  176.268  182.831  189.395  224
# 164  156.590  163.147  169.704  176.261  182.818  189.374  225
# 165  156.599  163.151  169.703  176.255  182.807  189.359  226
# 166  156.608  163.153  169.699  176.245  182.791  189.336  227
# 167  156.614  163.155  169.696  176.237  182.777  189.318  228
#
# [168 rows x 15 columns]

# %%
height_df_girl = pd.DataFrame()
height_df_girl['age'] = df_girl['age']
height_df_girl['id'] = df_girl['id']
height_df_girl['height'] = df_girl['height']
merged_gh = pd.merge(height_df_girl, gh, left_on='age', right_on='age', how='left')
merged_gh.set_index(df_girl.index, inplace=True)
# print(merged_gh)
# Calculate L * M * S and create a new column in df_girl
merged_gh['HZ'] = ((merged_gh['height']/merged_gh['M'])**merged_gh['L'] -1)/(merged_gh['L'] * merged_gh['S'])
# print(merged_df_girl)
# print(merged_df_girl['HZ'])
# Now you can use merged_df_girl to see the updated DataFrame
height_df_girl = merged_gh
# Show the updated df_girl with the new column
print(height_df_girl)
# Out:
#          age id  height  L         M       S   StDev  SD5neg  SD4neg  SD3neg  \
# bharani   83  4     141  1  120.3374  0.0452  5.4393  93.141   98.58  104.02
#
#           SD2neg   SD1neg      SD0      SD1      SD2      SD3      SD4  \
# bharani  109.459  114.898  120.337  125.777  131.216  136.655  142.094
#
#                HZ
# bharani  3.798795

# %%
weight_df_girl = pd.DataFrame()
weight_df_girl[['age','id','weight']] = df_girl[['age','id','weight']]
print(weight_df_girl)
# Out:
#          age id  weight
# bharani   83  4      28

# %%
gw = pd.read_excel("WFA_girls.xlsx")
gw['age']=gw['Month']
gw = gw.drop('Month',axis=1)
print(gw)
# Out:
#          L        M        S  SD4neg  SD3neg  SD2neg  SD1neg     SD0     SD1  \
# 0  -0.4681  18.2579  0.14295  10.742  12.352  13.961  15.899  18.258  21.169
# 1  -0.4711  18.4329  0.14350  10.828  12.456  14.083  16.043  18.433  21.386
# 2  -0.4742  18.6073  0.14404  10.915  12.559  14.204  16.187  18.607  21.601
# 3  -0.4773  18.7811  0.14459  11.000  12.662  14.324  16.330  18.781  21.817
# 4  -0.4803  18.9545  0.14514  11.085  12.764  14.444  16.473  18.954  22.032
# 5  -0.4834  19.1276  0.14569  11.169  12.866  14.564  16.616  19.128  22.247
# 6  -0.4864  19.3004  0.14624  11.253  12.968  14.683  16.758  19.300  22.462
# 7  -0.4894  19.4730  0.14679  11.337  13.069  14.801  16.899  19.473  22.677
# 8  -0.4924  19.6455  0.14735  11.419  13.169  14.919  17.041  19.646  22.893
# 9  -0.4954  19.8180  0.14790  11.503  13.270  15.038  17.182  19.818  23.108
# 10 -0.4984  19.9908  0.14845  11.586  13.371  15.156  17.323  19.991  23.324
# 11 -0.5013  20.1639  0.14900  11.669  13.471  15.274  17.465  20.164  23.541
# 12 -0.5043  20.3377  0.14955  11.752  13.572  15.393  17.607  20.338  23.759
# 13 -0.5072  20.5124  0.15010  11.835  13.673  15.512  17.750  20.512  23.978
# 14 -0.5100  20.6885  0.15065  11.919  13.775  15.632  17.893  20.688  24.199
# 15 -0.5129  20.8661  0.15120  12.004  13.878  15.753  18.038  20.866  24.423
# 16 -0.5157  21.0457  0.15175  12.089  13.982  15.875  18.185  21.046  24.648
# 17 -0.5185  21.2274  0.15230  12.175  14.087  15.998  18.333  21.227  24.877
# 18 -0.5213  21.4113  0.15284  12.263  14.193  16.124  18.483  21.411  25.108
# 19 -0.5240  21.5979  0.15339  12.352  14.301  16.250  18.635  21.598  25.343
# 20 -0.5268  21.7872  0.15393  12.443  14.411  16.379  18.790  21.787  25.581
# 21 -0.5294  21.9795  0.15448  12.534  14.522  16.510  18.947  21.980  25.823
# 22 -0.5321  22.1751  0.15502  12.627  14.635  16.643  19.106  22.175  26.069
# 23 -0.5347  22.3740  0.15556  12.722  14.750  16.779  19.268  22.374  26.320
# 24 -0.5372  22.5762  0.15610  12.819  14.867  16.916  19.433  22.576  26.574
# 25 -0.5398  22.7816  0.15663  12.917  14.987  17.056  19.601  22.782  26.832
#
#        SD2     SD3     SD4  age
# 0   24.817  29.468  34.118   61
# 1   25.090  29.823  34.555   62
# 2   25.363  30.178  34.992   63
# 3   25.637  30.535  35.433   64
# 4   25.911  30.893  35.876   65
# 5   26.185  31.253  36.321   66
# 6   26.460  31.614  36.768   67
# 7   26.735  31.977  37.218   68
# 8   27.011  32.342  37.673   69
# 9   27.288  32.708  38.129   70
# 10  27.566  33.077  38.589   71
# 11  27.845  33.448  39.051   72
# 12  28.126  33.822  39.519   73
# 13  28.409  34.200  39.991   74
# 14  28.695  34.581  40.468   75
# 15  28.983  34.968  40.953   76
# 16  29.276  35.360  41.443   77
# 17  29.572  35.757  41.942   78
# 18  29.871  36.158  42.446   79
# 19  30.176  36.568  42.960   80
# 20  30.485  36.983  43.482   81
# 21  30.799  37.406  44.013   82
# 22  31.118  37.836  44.554   83
# 23  31.443  38.274  45.104   84
# 24  31.773  38.719  45.664   85
# 25  32.109  39.171  46.232   86
# 26  32.450  39.632  46.813   87
# 27  32.796  40.099  47.401   88
# 28  33.149  40.574  48.000   89
# 29  33.507  41.058  48.610   90
# 30  33.870  41.549  49.228   91
# 31  34.239  42.048  49.857   92
# 32  34.614  42.555  50.497   93
# 33  34.996  43.072  51.149   94
# 34  35.383  43.596  51.809   95
# 35  35.776  44.128  52.481   96
# 36  36.176  44.670  53.164   97
# 37  36.582  45.220  53.858   98
# 38  36.994  45.778  54.562   99
# 39  37.412  46.343  55.275  100
# 40  37.836  46.918  55.999  101
# 41  38.265  47.499  56.734  102
# 42  38.702  48.092  57.481  103
# 43  39.142  48.688  58.233  104
# 44  39.589  49.293  58.997  105
# 45  40.041  49.906  59.771  106
# 46  40.497  50.525  60.552  107
# 47  40.958  51.149  61.340  108
# 48  41.424  51.781  62.138  109
# 49  41.895  52.419  62.944  110
# 50  42.370  53.063  63.755  111
# 51  42.851  53.714  64.578  112
# 52  43.335  54.371  65.407  113
# 53  43.826  55.035  66.244  114
# 54  44.321  55.705  67.089  115
# 55  44.823  56.385  67.947  116
# 56  45.329  57.069  68.809  117
# 57  45.843  57.764  69.685  118
# 58  46.363  58.465  70.568  119
# 59  46.890  59.177  71.465  120

# %%
merged_gw = pd.DataFrame()
# print(merged_gw)
merged_gw = pd.merge(weight_df_girl, gw, left_on='age', right_on='age', how='left')
merged_gw.set_index(df_girl.index, inplace=True)
# print(merged_gw)
# Calculate L * M * S and create a new column in df_girl
merged_gw['WZ'] = ((merged_gw['weight']/merged_gw['M'])**merged_gw['L'] -1)/(merged_gw['L'] * merged_gw['S'])
# print(merged_df_girl)
# print(merged_df_girl['WZ'])
# Now you can use merged_df_girl to see the updated DataFrame
weight_df_girl = merged_gw
# Show the updated df_girl with the new column
print(weight_df_girl)
# Out:
#          age id  weight       L        M        S  SD4neg  SD3neg  SD2neg  \
# bharani   83  4      28 -0.5321  22.1751  0.15502  12.627  14.635  16.643
#
#          SD1neg     SD0     SD1     SD2     SD3     SD4       WZ
# bharani  19.106  22.175  26.069  31.118  37.836  44.554  1.41493

# %%
gb = pd.read_excel("BFA_girls.xlsx")
gb['age']=gb['Month']
gb = gb.drop('Month',axis=1)
print(gb)
# Out:
#           L        M        S  SD4neg  SD3neg  SD2neg  SD1neg     SD0     SD1  \
# 0   -0.8886  15.2441  0.09692  10.793  11.770  12.748  13.891  15.244  16.870
# 1   -0.9068  15.2434  0.09738  10.786  11.763  12.741  13.885  15.243  16.879
# 2   -0.9248  15.2433  0.09783  10.780  11.757  12.734  13.881  15.243  16.889
# 3   -0.9427  15.2438  0.09829  10.775  11.752  12.728  13.876  15.244  16.900
# 4   -0.9605  15.2448  0.09875  10.770  11.746  12.723  13.872  15.245  16.911
# ..      ...      ...      ...     ...     ...     ...     ...     ...     ...
# 163 -0.7819  21.3752  0.14405  12.977  14.731  16.484  18.648  21.375  24.905
# 164 -0.7738  21.3884  0.14414  12.971  14.729  16.488  18.657  21.388  24.920
# 165 -0.7658  21.4014  0.14423  12.964  14.728  16.491  18.665  21.401  24.935
# 166 -0.7577  21.4143  0.14432  12.958  14.726  16.494  18.673  21.414  24.951
# 167 -0.7496  21.4269  0.14441  12.951  14.724  16.497  18.681  21.427  24.965
#
#         SD2     SD3     SD4  age
# 0    18.858  21.340  23.821   61
# 1    18.886  21.403  23.920   62
# 2    18.915  21.468  24.020   63
# 3    18.946  21.535  24.123   64
# 4    18.977  21.603  24.230   65
# ..      ...     ...     ...  ...
# 163  29.626  36.219  42.812  224
# 164  29.637  36.209  42.781  225
# 165  29.649  36.200  42.751  226
# 166  29.659  36.190  42.720  227
# 167  29.670  36.179  42.689  228
#
# [168 rows x 13 columns]

# %%
bmi_df_girl = pd.DataFrame()
bmi_df_girl[['age','id','BMI']] = df_girl[['age','id','BMI']]
print(bmi_df_girl)
# Out:
#          age id    BMI
# bharani   83  4  14.08

# %%
merged_gb = pd.DataFrame()
# print(merged_gb)
merged_gb = pd.merge(bmi_df_girl, gb, left_on='age', right_on='age', how='left')
merged_gb.set_index(df_girl.index, inplace=True)
# print(merged_gb)
# Calculate L * M * S and create a new column in df_girl
merged_gb['BZ'] = ((merged_gb['BMI']/merged_gb['M'])**merged_gb['L'] -1)/(merged_gb['L'] * merged_gb['S'])
# print(merged_gb)
# print(merged_gb['BZ'])
# Now you can use merged_df_girl to see the updated DataFrame
bmi_df_girl = merged_gb
# Show the updated df_girl with the new column
print(bmi_df_girl)
# Out:
#          age id    BMI       L        M      S  SD4neg  SD3neg  SD2neg  \
# bharani   83  4  14.08 -1.2433  15.3871  0.107  10.762  11.745  12.728
#
#          SD1neg     SD0     SD1     SD2     SD3     SD4        BZ
# bharani  13.916  15.387  17.259  19.734  23.178  26.621 -0.877183

# %% [markdown]
# \
#  GIRLS\
#  HEIGHT FOR AGE - height_df_girl  -> HZ Z-Score\
#  BMI FOR AGE - bmi_df_girl -> BZ Z-Score\
#  WEIGHT FOR AGE - weight_df_girl -> WZ Z-Score\
#  \
#  BOYS\
#  HEIGHT FOR AGE - height_df_boy -> HZ Z-Score\
#  BMI FOR AGE - bmi_df_boy -> BZ Z-Score\
#  WEIGHT FOR AGE - weight_df_boy -> WZ Z-Score\
# \

# %%
print(height_df_girl)
print(bmi_df_girl)
print(weight_df_girl)
# Out:
#          age id  height  L         M       S   StDev  SD5neg  SD4neg  SD3neg  \
# bharani   83  4     141  1  120.3374  0.0452  5.4393  93.141   98.58  104.02
#
#           SD2neg   SD1neg      SD0      SD1      SD2      SD3      SD4  \
# bharani  109.459  114.898  120.337  125.777  131.216  136.655  142.094
#
#                HZ
# bharani  3.798795
#          age id    BMI       L        M      S  SD4neg  SD3neg  SD2neg  \
# bharani   83  4  14.08 -1.2433  15.3871  0.107  10.762  11.745  12.728
#
#          SD1neg     SD0     SD1     SD2     SD3     SD4        BZ
# bharani  13.916  15.387  17.259  19.734  23.178  26.621 -0.877183
#          age id  weight       L        M        S  SD4neg  SD3neg  SD2neg  \
# bharani   83  4      28 -0.5321  22.1751  0.15502  12.627  14.635  16.643
#
#          SD1neg     SD0     SD1     SD2     SD3     SD4       WZ
# bharani  19.106  22.175  26.069  31.118  37.836  44.554  1.41493

# %%
print(height_df_boy)
print(bmi_df_boy)
print(weight_df_boy)
# Out:
#          age id  height  L         M        S   StDev  SD5neg  SD4neg  \
# goutham   78  2     110  1  118.8700  0.04295  5.1055  93.343  98.448
# john123   65  3     130  1  112.3895  0.04195  4.7147  88.816  93.531
#
#           SD3neg   SD2neg   SD1neg     SD0      SD1      SD2      SD3  \
# goutham  103.554  108.659  113.765  118.87  123.975  129.081  134.186
# john123   98.245  102.960  107.675  112.39  117.104  121.819  126.534
#
#              SD4        HZ
# goutham  139.292 -1.737353
# john123  131.248  3.735201
#          age id    BMI       L        M        S  SD4neg  SD3neg  SD2neg  \
# goutham   78  2  16.53 -1.1230  15.3825  0.08865  11.292  12.189  13.086
# john123   65  3  11.24 -0.8322  15.2619  0.08490  11.207  12.114  13.021
#
#          SD1neg     SD0     SD1     SD2     SD3     SD4        BZ
# goutham  14.136  15.382  16.888  18.745  21.097  23.449  0.779658
# john123  14.060  15.262  16.667  18.328  20.320  22.312 -4.102910
#          age id  weight       L        M        S  SD4neg  SD3neg  SD2neg  \
# goutham   78  2      20 -0.3804  21.6810  0.13554   12.96  14.855  16.751
# john123   65  3      19 -0.2443  19.2132  0.13142   11.48  13.186  14.892
#
#          SD1neg     SD0     SD1     SD2     SD3     SD4        WZ
# goutham  18.997  21.681  24.918  28.862  33.723  38.583 -0.604660
# john123  16.882  19.213  21.959  25.210  29.083  32.956 -0.085023

# %%
height_df_girl.to_excel('height_df_girl.xlsx', index=True, index_label='Name')
bmi_df_girl.to_excel('bmi_df_girl.xlsx', index=True, index_label='Name')
weight_df_girl.to_excel('weight_df_girl.xlsx', index=True, index_label='Name')
height_df_boy.to_excel('height_df_boy.xlsx', index=True, index_label='Name')
bmi_df_boy.to_excel('bmi_df_boy.xlsx', index=True, index_label='Name')
weight_df_boy.to_excel('weight_df_boy.xlsx', index=True, index_label='Name')
